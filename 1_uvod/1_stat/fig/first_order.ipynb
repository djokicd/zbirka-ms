# %%
from pylab import *
from ms_lib import *

# %%
n = 1e4
C = 14.07e-9 
L = 180e-6
R = 1e3

w = np.logspace(1, 10, 1000)
s = 1j*w
H = 1/n * s/C / (s**2 + s/(R*C) + 1/(L*C))

# %%
generate_canvas()
t = np.linspace(0, 100, 1001)
tau = 10
step = 1 - exp(-t/tau)
plt.plot(t, step, 'k')
xlim(0, 60)
xlabel(r"$t\rm\,{[s]}$")
ylabel(r"$v/(\upalpha \Delta T)$")
plt.savefig("../../2_din/fig/h_first_order_step.pdf", bbox_inches='tight')

# %%
# %source ../../../../venv/bin/activate
# Out:
# UsageError: Line magic function `%source` not found.

# %%
# %ls ../../../../venv/bin
# Out:
# activate      activate.fish  pip*   pip3.12*  python3@
# activate.csh  Activate.ps1   pip3*  python@   python3.12@

# %%
jupyter kernelspec list
# Out:
#   Cell In[86], line 1
#     jupyter kernelspec list
#             ^
# SyntaxError: invalid syntax
